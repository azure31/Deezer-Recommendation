# %%
import unirest
track_id= str(13766137)
response = unirest.get("https://deezerdevs-deezer.p.mashape.com/track/"+ track_id,
  headers={
    "X-Mashape-Key": "C0Z2nJ1lh6mshU79YZYFkHyTDvDEp1M6Rz8jsnsCpPxB0hqPXg",
    "Accept": "text/plain"
  }
)

# %%
print "stream link:  \n"
print response.body['preview']  #link to play song preview
response.body
# Out:
# stream link
#
# http://e-cdn-preview-6.deezer.com/stream/6fdb966d140fe58f53c85ef7727d3d18-3.mp3
# {u'album': {u'cover': u'https://api.deezer.com/album/1259714/image',
#   u'cover_big': u'https://e-cdns-images.dzcdn.net/images/cover/d6b31465ff4f9574c73dd287c2813db4/500x500-000000-80-0-0.jpg',
#   u'cover_medium': u'https://e-cdns-images.dzcdn.net/images/cover/d6b31465ff4f9574c73dd287c2813db4/250x250-000000-80-0-0.jpg',
#   u'cover_small': u'https://e-cdns-images.dzcdn.net/images/cover/d6b31465ff4f9574c73dd287c2813db4/56x56-000000-80-0-0.jpg',
#   u'cover_xl': u'https://e-cdns-images.dzcdn.net/images/cover/d6b31465ff4f9574c73dd287c2813db4/1000x1000-000000-80-0-0.jpg',
#   u'id': 1259714,
#   u'link': u'https://www.deezer.com/album/1259714',
#   u'release_date': u'2011-09-26',
#   u'title': u'\xc0 toute \xe9preuve',
#   u'tracklist': u'https://api.deezer.com/album/1259714/tracks',
#   u'type': u'album'},
#  u'artist': {u'id': 460,
#   u'link': u'https://www.deezer.com/artist/460',
# ...

# %% [markdown]
# potentially useful vars: role, gain, rank, track_position?

# %%
genre_id= str(16)
response = unirest.get("https://deezerdevs-deezer.p.mashape.com/genre/"+ genre_id,
  headers={
    "X-Mashape-Key": "C0Z2nJ1lh6mshU79YZYFkHyTDvDEp1M6Rz8jsnsCpPxB0hqPXg",
    "Accept": "text/plain"
  }
)


print response.body
# Out:
# {u'picture': u'https://api.deezer.com/genre/16/image', u'name': u'Musique asiatique', u'picture_medium': u'https://e-cdns-images.dzcdn.net/images/misc/dd6d2756465b22488dff5d8663e86688/250x250-000000-80-0-0.jpg', u'picture_small': u'https://e-cdns-images.dzcdn.net/images/misc/dd6d2756465b22488dff5d8663e86688/56x56-000000-80-0-0.jpg', u'picture_xl': u'https://e-cdns-images.dzcdn.net/images/misc/dd6d2756465b22488dff5d8663e86688/1000x1000-000000-80-0-0.jpg', u'type': u'genre', u'id': 16, u'picture_big': u'https://e-cdns-images.dzcdn.net/images/misc/dd6d2756465b22488dff5d8663e86688/500x500-000000-80-0-0.jpg'}

# %%
artist_id= str(2939)
response = unirest.get("https://deezerdevs-deezer.p.mashape.com/artist/"+ artist_id,
  headers={
    "X-Mashape-Key": "C0Z2nJ1lh6mshU79YZYFkHyTDvDEp1M6Rz8jsnsCpPxB0hqPXg",
    "Accept": "text/plain"
  }
)


print response.body
# Out:
# {u'nb_fan': 28290, u'picture': u'https://api.deezer.com/artist/2939/image', u'name': u'The Byrds', u'picture_medium': u'https://e-cdns-images.dzcdn.net/images/artist/3297450b784e516e9cd9146f93816161/250x250-000000-80-0-0.jpg', u'nb_album': 23, u'share': u'http://www.deezer.com/artist/2939?utm_source=deezer&utm_content=artist-2939&utm_term=0_1492508981&utm_medium=web', u'picture_small': u'https://e-cdns-images.dzcdn.net/images/artist/3297450b784e516e9cd9146f93816161/56x56-000000-80-0-0.jpg', u'link': u'https://www.deezer.com/artist/2939', u'type': u'artist', u'radio': True, u'picture_xl': u'https://e-cdns-images.dzcdn.net/images/artist/3297450b784e516e9cd9146f93816161/1000x1000-000000-80-0-0.jpg', u'tracklist': u'https://api.deezer.com/artist/2939/top?limit=50', u'id': 2939, u'picture_big': u'https://e-cdns-images.dzcdn.net/images/artist/3297450b784e516e9cd9146f93816161/500x500-000000-80-0-0.jpg'}

# %%
album_id= str(71718)
response = unirest.get("https://deezerdevs-deezer.p.mashape.com/album/"+ album_id,
  headers={
    "X-Mashape-Key": "C0Z2nJ1lh6mshU79YZYFkHyTDvDEp1M6Rz8jsnsCpPxB0hqPXg",
    "Accept": "text/plain"
  }
)


print response.body
# Out:
# {u'rating': 0, u'contributors': [{u'picture': u'https://api.deezer.com/artist/2939/image', u'name': u'The Byrds', u'picture_medium': u'https://e-cdns-images.dzcdn.net/images/artist/3297450b784e516e9cd9146f93816161/250x250-000000-80-0-0.jpg', u'type': u'artist', u'role': u'Main', u'share': u'http://www.deezer.com/artist/2939?utm_source=deezer&utm_content=artist-2939&utm_term=0_1492509071&utm_medium=web', u'picture_small': u'https://e-cdns-images.dzcdn.net/images/artist/3297450b784e516e9cd9146f93816161/56x56-000000-80-0-0.jpg', u'link': u'https://www.deezer.com/artist/2939', u'radio': True, u'picture_xl': u'https://e-cdns-images.dzcdn.net/images/artist/3297450b784e516e9cd9146f93816161/1000x1000-000000-80-0-0.jpg', u'tracklist': u'https://api.deezer.com/artist/2939/top?limit=50', u'id': 2939, u'picture_big': u'https://e-cdns-images.dzcdn.net/images/artist/3297450b784e516e9cd9146f93816161/500x500-000000-80-0-0.jpg'}], u'share': u'http://www.deezer.com/album/71718?utm_source=deezer&utm_co
# ...

# %% [markdown]
# potentially useful vars: rating, rank?
